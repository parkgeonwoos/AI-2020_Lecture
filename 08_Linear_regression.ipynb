# %%
import tensorflow.compat.v1 as tf 
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x_train = [1, 2, 3]

# %%
y_train = [2+1 +0.1, 4+1 -0.2, 6+1 +0.15]

# %%
plt.plot(x_train, y_train,'.-')
plt.xlabel('X') 
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ##초기화,Initializtion

# %%
w0= 8;
b0= -22;

# %%
W = tf.Variable(w0*tf.ones([1]), name='weight') 
b = tf.Variable(b0*tf.ones([1]), name='bias')

# %%
hypothesis = x_train * W + b

# %% [markdown]
# cost/loss function

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# ####optimizer 설정

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
#optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
nb_epoch = 2000

# %% [markdown]
# ## 실행 과정

# %%
for i in range(100):    
  if i % 20 ==0:        
    print(i)
# Out:
# 0
# 20
# 40
# 60
# 80

# %%
vw = [] # empty list 
vb = [] 
vcost = []

# %%
for step in range(nb_epoch+1):    
  sess.run(train)    
  w1 = sess.run(W)[0] # slope    
  b1 = sess.run(b)[0] # bias    
  cost1 = sess.run(cost)        
  vw.append(w1)    
  vb.append(b1)    
  vcost.append(cost1)        
  if step % 100 == 0:       
    print(step, '--', cost1, '--',  w1, '--', b1)
# Out:
# 0 -- 128.27895 -- 8.361 -- -21.779667
# 100 -- 40.596073 -- 9.422943 -- -15.850663
# 200 -- 25.094873 -- 7.840476 -- -12.253278
# 300 -- 15.516083 -- 6.5964956 -- -9.425417
# 400 -- 9.596971 -- 5.6186132 -- -7.202461
# 500 -- 5.9393144 -- 4.8499074 -- -5.4550123
# 600 -- 3.679104 -- 4.245635 -- -4.081359
# 700 -- 2.28243 -- 3.7706213 -- -3.001541
# 800 -- 1.419371 -- 3.3972175 -- -2.1527061
# 900 -- 0.8860528 -- 3.103688 -- -1.4854447
# 1000 -- 0.55649465 -- 2.8729472 -- -0.9609166
# 1100 -- 0.3528478 -- 2.6915638 -- -0.54858947
# 1200 -- 0.22700632 -- 2.54898 -- -0.22446284
# 1300 -- 0.14924389 -- 2.4368963 -- 0.030330364
# 1400 -- 0.10119158 -- 2.348788 -- 0.23062068
# 1500 -- 0.071498044 -- 2.2795267 -- 0.38806728
# 1600 -- 0.053149253 -- 2.225081 -- 0.51183486
# 1700 -- 0.041810792 -- 2.1822822 -- 0.60912716
# 1800 -- 0.034804314 -- 2.148638 -- 0.6856081
# 1900 -- 0.030474758 -- 2.122191 -- 0.7457293
# 2000 -- 0.027799344 -- 2.1014009 -- 0.79298943

# %%
w1 = sess.run(W)[0] # slope 
b1 = sess.run(b)[0] # bias 
str1 = 'y={:.3}x + {:.3}'.format(w1, b1) 
print(w1, b1) 
print(str1)
# Out:
# 2.1014009 0.79298943
# y=2.1x + 0.793

# %%
plt.figure(1) 
plt.plot(x_train, y_train,'o') 
x1 = np.min(x_train)-1, np.max(x_train)+1 
y1 = np.dot(w1,x1) + b1 
plt.plot(x1, y1)
plt.grid() 
plt.xlabel('epoch') 
plt.title(str1)
# Out:
# Text(0.5, 1.0, 'y=2.1x + 0.793')

# %%
plt.plot(vb) 
plt.grid() 
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
plt.plot(vw)

# %%
plt.plot(vcost)

# %%
plt.plot(vb)
plt.plot(vw)
plt.legend(['b','w'])
plt.grid()
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
plt.plot(vcost)
